# %% [markdown]
# # N-Hance Implementation

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
def make_ordered_pairs(sentence):
    ans = list()
    for index, word in enumerate(sentence):
        temp = index
        while(temp != len(sentence) - 1):
            ans.append((sentence[index], sentence[temp]))
            temp += 1
    return ans

# %%
sentences = "This is a sample sentence, showing off the stop words filtration."
  
stop_words = set(stopwords.words('english')) 


for sentence in sentences:
    word_tokens = word_tokenize(example_sent) 
    filtered_sentence = [w for w in word_tokens if not w in stop_words]
    pairs = make_ordered_pairs(filtered_sentence)
    print(pairs)
  
# print(word_tokens) 
# print(filtered_sentence)
# Out:
# [('This', 'This'), ('This', 'sample'), ('This', 'sentence'), ('This', ','), ('This', 'showing'), ('This', 'stop'), ('This', 'words'), ('This', 'filtration'), ('sample', 'sample'), ('sample', 'sentence'), ('sample', ','), ('sample', 'showing'), ('sample', 'stop'), ('sample', 'words'), ('sample', 'filtration'), ('sentence', 'sentence'), ('sentence', ','), ('sentence', 'showing'), ('sentence', 'stop'), ('sentence', 'words'), ('sentence', 'filtration'), (',', ','), (',', 'showing'), (',', 'stop'), (',', 'words'), (',', 'filtration'), ('showing', 'showing'), ('showing', 'stop'), ('showing', 'words'), ('showing', 'filtration'), ('stop', 'stop'), ('stop', 'words'), ('stop', 'filtration'), ('words', 'words'), ('words', 'filtration'), ('filtration', 'filtration')]
# ...
